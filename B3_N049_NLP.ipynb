# %% [markdown]
# Natural Language Processing (NLP) Algorithm Project

# %% [markdown]
# Tarun Tanmay, N049
#
# Jai Verma, N060
#
# MBATech CE, Sem 5

# %%
#importing nltk package to use NLP
import nltk 
nltk.download('inaugural') #Downloading inaugural named corpus from nltk package 
from nltk.corpus import inaugural #importing the inaugural from the nltk corpus library ̀
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     /Users/tjrox0825/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!

# %%
inaugural.fileids() 
#Checking the file id of the inaugural named corpus
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %% [markdown]
# All the file ids are displayed that represent the year-President of America.
# The corpus includes the speech of several Presidents of America in the form of text files.

# %%
#checking all the years and displaying them 
[fileid[:4] for fileid in inaugural.fileids()]
# Out:
# ['1789',
#  '1793',
#  '1797',
#  '1801',
#  '1805',
#  '1809',
#  '1813',
#  '1817',
#  '1821',
#  '1825',
#  '1829',
#  '1833',
#  '1837',
#  '1841',
#  '1845',
#  '1849',
#  '1853',
#  '1857',
#  '1861',
#  '1865',
#  '1869',
#  '1873',
#  '1877',
#  '1881',
#  '1885',
#  '1889',
#  '1893',
#  '1897',
#  '1901',
#  '1905',
#  '1909',
#  '1913',
#  '1917',
#  '1921',
#  '1925',
#  '1929',
#  '1933',
#  '1937',
#  '1941',
#  '1945',
#  '1949',
#  '1953',
#  '1957',
#  '1961',
#  '1965',
#  '1969',
#  '1973',
#  '1977',
#  '1981',
#  '1985',
#  '1989',
#  '1993',
#  '1997',
#  '2001',
#  '2005',
#  '2009',
#  '2013',
#  '2017']

# %% [markdown]
# first four charachters of the file id is the year we will set as the field to search our targets.

# %%
table = nltk.ConditionalFreqDist((target, fileid[:4]) #The Conditional Frequency Distribution creates a table for searching the target in our fileid 
for fileid in inaugural.fileids() #we remove the stop words from our text files when we use the CFD function
for w in inaugural.words(fileid) #w will store the words we put in target
for target in ['america', 'citizen','war'] #setting targets to be searched   
if w.lower().startswith(target)) #w stores the target words, converts them into lower case 
table.tabulate(conditions=['america', 'citizen','war'], samples=['1841', '1993','2009']) #sample here indicates the years or the fileids in which our targets will be searched.
# Out:
#         1841 1993 2009
# america    7   33   15
# citizen   38    2    2
#     war    7    3    3

# %% [markdown]
# Total = 110, The counter (set here with variable name 'w' increases everytime when it finds the the target multiple times in specific fields.

# %%
table.plot()#plotting the scatterplot
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# The curve represents the counter w on y axis (the required output) against the fileids (years) in which the target is found multiple times.
